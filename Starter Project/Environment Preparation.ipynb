# %%
# !wget https://julialang-s3.julialang.org/bin/linux/x64/1.1/julia-1.1.0-linux-x86_64.tar.gz
# Out:
# --2019-01-26 13:48:24--  https://julialang-s3.julialang.org/bin/linux/x64/1.1/julia-1.1.0-linux-x86_64.tar.gz
# Resolving julialang-s3.julialang.org (julialang-s3.julialang.org)... 151.101.2.49, 151.101.66.49, 151.101.130.49, ...
# Connecting to julialang-s3.julialang.org (julialang-s3.julialang.org)|151.101.2.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89632491 (85M) [application/octet-stream]
# Saving to: ‘julia-1.1.0-linux-x86_64.tar.gz’
#
# julia-1.1.0-linux-x 100%[===================>]  85.48M   257MB/s    in 0.3s
#
# 2019-01-26 13:48:25 (257 MB/s) - ‘julia-1.1.0-linux-x86_64.tar.gz’ saved [89632491/89632491]

# %%
# !tar -xzf julia-1.1.0-linux-x86_64.tar.gz -C /usr --strip-components 1

# %%
# !julia -e 'using Pkg; pkg"add IJulia; add CuArrays; add Flux; precompile"'
# Out:
#    Cloning default registries into `~/.julia`
#    Cloning registry from "https://github.com/JuliaRegistries/General.git"
#      Added registry `General` to `~/.julia/registries/General`
#  Resolving package versions...
#  Installed Compat ────────── v1.4.0
#  Installed SoftGlobalScope ─ v1.0.9
#  Installed Conda ─────────── v1.1.1
#  Installed IJulia ────────── v1.15.2
#  Installed ZMQ ───────────── v1.0.0
#  Installed MbedTLS ───────── v0.6.6
#  Installed JSON ──────────── v0.20.0
#  Installed BinaryProvider ── v0.5.3
#  Installed VersionParsing ── v1.1.3
#   Updating `~/.julia/environments/v1.1/Project.toml`
#   [7073ff75] + IJulia v1.15.2
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#   [b99e7846] + BinaryProvider v0.5.3
#   [34da2185] + Compat v1.4.0
#   [8f4d0f93] + Conda v1.1.1
#   [7073ff75] + IJulia v1.15.2
#   [682c06a0] + JSON v0.20.0
#   [739be429] + MbedTLS v0.6.6
#   [b85f4697] + SoftGlobalScope v1.0.9
#   [81def892] + VersionParsing v1.1.3
# ...

# %%
#Displaying a list of available language kernels, you should find julia-1.1 kernel
# !jupyter-kernelspec list
# Out:
# Available kernels:
#   julia-1.1    /root/.local/share/jupyter/kernels/julia-1.1
#   python2      /usr/local/share/jupyter/kernels/python2
#   python3      /usr/local/share/jupyter/kernels/python3
#   swift        /usr/local/share/jupyter/kernels/swift

# %%
# Downloading dataset
# !mkdir Dataset
# !git clone https://github.com/circulosmeos/gdown.pl.git gdown
# !./gdown/gdown.pl https://drive.google.com/open?id=1A_UiJypNyMhHeFTnHApBdQo5Zp42WPAK Dataset/train.tar.xz
# !./gdown/gdown.pl https://drive.google.com/open?id=1J6ShxoGJXhA9quTMX-hN8TbUYdsycGhT Dataset/train.csv
# !./gdown/gdown.pl https://drive.google.com/open?id=1ANvvA_ddm4ur1q-3haW_PWBvsZIoEviC Dataset/test.zip
# !./gdown/gdown.pl https://drive.google.com/open?id=1u9b83EEZdvBlx0lCPoCPVz_mrWb-792X Dataset/sample_submission.csv
# !./gdown/gdown.pl https://drive.google.com/open?id=1VT2WezTPg1lapbLiRdNsLt0n4jH_M0Kp Dataset/train_original.csv
# !./gdown/gdown.pl https://drive.google.com/open?id=16nfvY6Ut-yjPmlr0KofNiAPlJwgVRbKA Dataset/train_original.zip
# Out:
# Cloning into 'gdown'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 70 (delta 15), reused 26 (delta 12), pack-reused 40
# Unpacking objects: 100% (70/70), done.
# Cannot open cookies file ‘gdown.cookie.temp’: No such file or directory
# --2019-02-02 12:44:50--  https://docs.google.com/uc?id=1A_UiJypNyMhHeFTnHApBdQo5Zp42WPAK&export=download
# Resolving docs.google.com (docs.google.com)... 108.177.97.102, 108.177.97.113, 108.177.97.138, ...
# Connecting to docs.google.com (docs.google.com)|108.177.97.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-08-7g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/mhmva62hdrrnqdctjnksm69bdn5oe5tl/1549108800000/09284792646027795976/*/1A_UiJypNyMhHeFTnHApBdQo5Zp42WPAK?e=download [following]
# ...

# %%
# Extracting Data
# %cd Dataset
# !tar -xf train.tar.xz
# !unzip test.zip
# !mkdir train_original
# !unzip -x train_original.zip -d train_original
# !mv train_original/train/* train_original/
# !rmdir train_original/train/
# %cd ..
# Out:
# /content/Dataset
# Archive:  test.zip
#    creating: test/
#   inflating: test/c55a35a7.jpg
#   inflating: test/7f48832c.jpg
#   inflating: test/28d4e63b.jpg
#   inflating: test/3a2310b3.jpg
#   inflating: test/c779125a.jpg
#   inflating: test/bd26dddf.jpg
#   inflating: test/dbbcc754.jpg
#   inflating: test/9045302f.jpg
#   inflating: test/ed2db5ae.jpg
#   inflating: test/cbd5ac86.jpg
#   inflating: test/53cd0f31.jpg
#   inflating: test/513da9dc.jpg
#   inflating: test/f3d633e0.jpg
#   inflating: test/b558ef5b.jpg
#   inflating: test/0372c7d4.jpg
#   inflating: test/7275e6ad.jpg
#   inflating: test/63cb943a.jpg
#   inflating: test/048512e2.jpg
#   inflating: test/8c3282a1.jpg
#   inflating: test/65d9a84d.jpg
#   inflating: test/3273f6a7.jpg
#   inflating: test/618be8d2.jpg
#   inflating: test/eb71a504.jpg
#   inflating: test/8c411469.jpg
#   inflating: test/4505e616.jpg
#   inflating: test/5e19225f.jpg
#   inflating: test/452f3107.jpg
#   inflating: test/5ebd411a.jpg
# ...
